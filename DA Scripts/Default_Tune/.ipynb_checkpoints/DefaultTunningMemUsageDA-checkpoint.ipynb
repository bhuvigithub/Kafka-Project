# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# DA on the Memory Usage of Broker-1
df1b = pd.read_csv("Brok1mem_usage.csv")
df1b.drop(['name'], axis=1, inplace=True)
df1b['timestamp'] = pd.to_datetime(df1b['timestamp'], unit='s')
df1b.head()
# Out:
#             timestamp     values                         pod
# 0 2021-07-30 14:30:05  819666944  my-cluster-metrics-kafka-0
# 1 2021-07-30 14:30:20  830980096  my-cluster-metrics-kafka-0
# 2 2021-07-30 14:30:31  839016448  my-cluster-metrics-kafka-0
# 3 2021-07-30 14:30:45  859758592  my-cluster-metrics-kafka-0
# 4 2021-07-30 14:30:59  870666240  my-cluster-metrics-kafka-0

# %%
#Average Memory Usage before rebalancing
membr1 = df1b[(df1b['timestamp'] >= '2021-07-30 14:30:20') & (df1b['timestamp'] <= '2021-07-30 15:01:53')]
membr1.head(3)
membr1avg = membr1['values'].mean()
print(membr1avg)
membr1.describe()
# Out:
# 1897181782.646154
#              values
# count  1.300000e+02
# mean   1.897182e+09
# std    6.223991e+08
# min    8.309801e+08
# 25%    1.291467e+09
# 50%    1.995866e+09
# 75%    2.570372e+09
# max    2.698543e+09

# %%
#Average Memory Usage During rebalancing
memdr1 = df1b[(df1b['timestamp'] >= '2021-07-30 15:02:13') & (df1b['timestamp'] <= '2021-07-30 15:07:13')]
memdr1.head(3)
memdr1avg = memdr1['values'].mean()
print(memdr1avg)
memdr1.describe()
# Out:
# 2593510022.736842
#              values
# count  1.900000e+01
# mean   2.593510e+09
# std    6.001937e+07
# min    2.470445e+09
# 25%    2.560549e+09
# 50%    2.607129e+09
# 75%    2.652957e+09
# max    2.668671e+09

# %%
#T-Stats Analysis
from scipy.stats import ttest_ind
resb1mem = ttest_ind(memdr1['values'], membr1['values'])
print(resb1mem)
# Out:
# Ttest_indResult(statistic=4.859399766881067, pvalue=2.9866455651537817e-06)

# %%
membr1.drop(['pod'], axis=1, inplace=True)
membr1.head(10)
membr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 1 to 130
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  130 non-null    datetime64[ns]
#  1   values     130 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.0 KB
# C:\Users\Bhuvi\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
memdr1.drop(['pod'], axis=1, inplace=True)
memdr1.head(10)
memdr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 131 to 149
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  19 non-null     datetime64[ns]
#  1   values     19 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 456.0 bytes

# %%
from datetime import datetime
m1=[]
for dat in df1b.timestamp:
    # print (dat)
    m1.append(datetime.strptime(str(dat), "%Y-%m-%d %H:%M:%S"))
fig1 = plt.figure(figsize=(10,4))
axe1 = fig1.add_axes([0.2, 0.1, 0.6, 0.8])
axe1.plot(m1,df1b['values'], 'g')
axe1.set_xlabel('time stamps')
axe1.set_ylabel('memory usage')
axe1.set_title('Broker1 Memory Utilization')
#fig1.tight_layout()
# Out:
# Text(0.5, 1.0, 'Broker1 Memory Utilization')

# %%
d=[]
for dat in membr1.timestamp:
    # print (dat)
    d.append(datetime.strptime(str(dat), "%Y-%m-%d %H:%M:%S"))
plt.plot(d,membr1['values'])
plt.xticks(rotation=360)
plt.xlabel('time stamps')
plt.ylabel('memory usage')
#axe1.xticks(rotation=90)
plt.title('Broker1 Memory Utilization before Rebalancing')
plt.show()

# %%
b=[]
for dat in memdr1.timestamp:
    # print (dat)
    b.append(datetime.strptime(str(dat), "%Y-%m-%d %H:%M:%S"))
plt.plot(b,memdr1['values'])
plt.xticks(rotation=360)
plt.xlabel('time stamps')
plt.ylabel('memory usage')
#axe1.xticks(rotation=90)
plt.title('Broker1 Memory Utilization during Rebalancing')
plt.show()

# %%
m=[]
for dat in df1b.timestamp:
    # print (dat)
    m.append(datetime.strptime(str(dat), "%Y-%m-%d %H:%M:%S"))
fig2 = plt.figure(figsize=(10,4))
axe1 = fig2.add_axes([0.2, 0.1, 0.6, 0.8])
axe1.plot(m,df1b['values'], 'g')
axe1.set_xlabel('time stamps')
axe1.set_ylabel('memory usage')
#axe1.xticks(rotation=90)
axe1.set_title('Broker1 Memory Utilization')
fig2.tight_layout()
# Out:
# <ipython-input-37-3102f5b2b4eb>:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig2.tight_layout()

# %%
# Out:
# <ipython-input-36-ac65e773ee4f>:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig2.tight_layout()
